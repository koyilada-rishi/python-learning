# %%
# Bubble sorting
def BubbleSort(l):
    n = len(l)
    for i in range(n-1):
        for j in range(n-i-1):
            if l[j] > l[j+1]:
                l[j],l[j+1] = l[j+1],l[j]
    return l
l=[10,8,20,5]
print(BubbleSort(l))

# %%
# if the list is sortted then check???

# Bubble sorting
def BubbleSort(l):
    n = len(l)
    for i in range(n-1):
        swapped = False
        for j in range(n-i-1):
            if l[j] > l[j+1]:
                l[j],l[j+1] = l[j+1],l[j]
                swapped = True
        if swapped == False:
            return l
    return l
l=[10,8,20,5]
print(BubbleSort(l))

# %%
# Selected Sorting

def Select_sort(l):
    n = len(l)
    for i in range(n-1):
        min_index = i
        for j in range (i+1,n):
            if l[j] < l[min_index]:
                min_index = j
                l[min_index],l[i] = l[i],l[min_index]
                
    return l
l= [10,5,8,20,2,18]
print(Select_sort(l))

# %%
# bubble sort practice
def Bubble_Sort(l):
    n = len(l)
    for i in range(n-1):
        for j in range(n-i-1):
            if l[j] > l[j+1]:
                l[j],l[j+1] = l[j+1],l[j]
    return l
l=[1,4,6,2,3,8]
print(Bubble_Sort(l))

# %%
# Practice selected sort
# dont use this evaluate this
def Selection_Sort(l):
    n = len(l)
    for i in range(n-1):
        min = i
        for j in range(i+1,n):
            if l[min] > l[j]:
                l[min],l[j] = l[j],l[min]
    return l
# l = [30,20,40,10]
l=[1,4,6,2,3,8]
print(Selection_Sort(l))

# %%
def Selection_Sort(l):
    n = len(l)
    for i in range(n-1):
        min = i  # Store the index of the smallest element
        for j in range(i+1, n):  # Look for a smaller element in the remaining array
            if l[min] > l[j]:  # If a smaller element is found, update min index
                min = j
        # Swap only once per iteration
        l[i], l[min] = l[min], l[i]
    return l

l=[1,4,6,2,3,8]
print(Selection_Sort(l))

# %%
# Insertion sort Practice

def Insertion_Sort(l):
    n = len(l)
    for i in range(1,n):
        j =i
        while j > 0 and l[j-1] > l[j]:
            l[j-1],l[j] = l[j],l[j-1]
            j = j - 1
l = [1,4,6,8,2,3,5,10]
Insertion_Sort(l)
print(l)

# %%
# dont use it my development
# Merge two sorted arrays
def merge_array(a,b):
    res = []
    j=0
    print(len(a))
    for i in range(len(a)):
        while  j < len(b) :
            if a[i] > b[j]:
                res.append(b[j])
                j = j+1
            else:
                res.append(a[i])
                break
        if j == len(b):
            res.append(a[i])
    while j < len(b):
        res.append(b[j])
        j = j+1
    return res
    

a = [1,3,5,7,9]
b = [2,4,6,8]

print(merge_array(a,b))

# %%
# My approach dont use it 
# Merge two sorted arrays
def merge_array(a,b):
    res = []
    j=0
    c=1
    for i in range(len(a)):
        while  j < len(b) :
            if a[i] > b[j]:
                res.append(b[j])
                j = j+1
            elif a[i] < b[j]:
                if i == len(a)-1 and res[len(res)-c] == a[i-1]: # last second values i am checking and then appending it
                    res.append(b[j])
                    if j != len(b)-1:
                        j = j+ 1
                        c = c + 1
                    else:
                        break
                else:
                    res.append(a[i])
                    break
            
        if j == len(b): # this is written cause if a len is more that b so b(j) will be done with while loop so rest of  the a values which are sorted one will be appended 
            res.append(a[i])

    print(res)
    

a = [10,15]
b = [5,6,6,30,40]
# a = [1,3,5,7,9,10]
# b = [2,4,6,8]

merge_array(a,b)

# %%
# Merge two sorted arrays
# Perfect one 
def ma_s(a,b):
    m = len(a)
    n = len(b)
    i =j=0
    res =[]
    while i < m and j<n:
        if a[i] < b[j]:
            res.append(a[i])
            i = i +1
        else:
            res.append(b[j])
            j = j + 1
    while i < m:
        res.append(a[i])
        i = i + 1
    while j < n:
        res.append(b[j])
        j = j + 1
    return res

a = [10,15]
b = [5,6,6,30,40]
# a = [1,3,5,7,9,10]
# b = [2,4,6,8]

print(ma_s(a,b))

# %%
# Merge sub arrays ex:  I/P a = [10,15,20,11,13] ; low = 0 ; high = 4 ; mid = 2
# create two arrays between low to mid and mid to high
# compare and merge those two sorted arrays

# # Merge two sorted arrays
def ma_s(a,b):
    m = len(a)
    n = len(b)
    i = 0
    j = 0
    res =[]
    while i < m and j < n:
        if a[i] < b[j]:
            res.append(a[i])
            i = i+1
        else:
            res.append(b[j])
            j = j+1
    while i < m:
            res.append(a[i])
            i = i+1
    while j < n:
            res.append(b[j])
            j = j+1
    return res

# slipping a and b arrays using low , mid , high and using ma_s() for sort array return
def merge_subarray(l,low,mid,high):
    j = 0
    a = []
    b = []
    m=len(a)
    n=len(b)
    if low < mid < high:
        while j < mid + 1 :
            a.append(l[j])
            j = j + 1
        while j < high + 1:
            b.append(l[j])
            j = j + 1
    print(f"I am a     {a}   \nI am b     {b}")
    return ma_s(a,b)

l=[10,15,20,11,13]
low = 0
high = 4
mid = 2
l = [10,15,20,40,8,11,55]
low = 0
mid = 3
high = 6

print(merge_subarray(l,low,mid,high))

# %%
# Merge sub arrays ex:  I/P a = [10,15,20,11,13] ; low = 0 ; high = 4 ; mid = 2
# create two arrays between low to mid and mid to high
# compare and merge those two sorted arrays

# slipping a and b arrays using low , mid , high and using ma_s() for sort array return
def merge(arr,low,mid,high):
    left = arr[low:mid+1]
    right = arr[mid+1:high+1]
    i = 0
    j = 0
    k = low
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            arr[k] = left[i]
            k = k + 1
            i = i + 1
        else:
            arr[k] = right[j]
            k = k + 1
            j = j + 1
    while i < len(left):
            arr[k] = left[i]
            k = k + 1
            i = i + 1
    while j < len(right):
            arr[k] = right[j]
            k = k + 1
            j = j + 1


# l=[10,15,20,11,13]
# low = 0
# high = 4
# mid = 2

# l = [10,15,20,40,8,11,55]
# low = 0
# mid = 3
# high = 6

# merge(l,low,mid,high)
# print(l)

# %%
def merge_sort(arr,low,high):
    if high > low :
        mid = (high + low)//2
        merge_sort(arr,low,mid)
        merge_sort(arr,mid+1,high)
        merge(arr,low,mid,high)

arr = [10,15,20,40,8,11,55]
low = 0
high = 6

merge_sort(arr,low,high)
print(arr)

# %%
# merge sort practice


def merges(arr,low,mid,high):
    left = arr[low:mid+1]
    right = arr[mid+1:high+1]
    i,j = 0,0
    k = low
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            arr[k] = left[i]
            k = k + 1
            i = i + 1
        else:
            arr[k] = right[j]
            k = k + 1
            j = j + 1
    while i < len(left):
        arr[k] = left[i]
        k = k + 1
        i = i + 1
    while j < len(right):
            arr[k] = right[j]
            k = k + 1
            j = j + 1
def merge_Sort(arr,low,high):
    if high > low :
        mid = (high + low)//2
        merge_Sort(arr,low,mid)
        merge_Sort(arr,mid + 1,high)
        merges(arr,low,mid,high)
        
arr = [10,15,20,40,8,11,55]
low = 0
high = 6

merge_Sort(arr,low,high)
print(arr)

# %%
import json

def bubble_sort(data):
    res = data[:]
    n = len(res)
    for i in range(n-1):
        for j in range(n-i-1):
            if res[j]["VIRT"] > res[j+1]["VIRT"]:
                res[j], res[j+1] = res[j+1], res[j]
    return res

def selection_sort(data):
    res = data[:]
    n = len(res)
    for i in range(n-1):
        min = i
        for j in range(i+1,n):
            if res[min]["VIRT"] > res[j]["VIRT"]:
                min = j
        res[i]["VIRT"],res[min]["VIRT"] = res[min]["VIRT"],res[i]["VIRT"]
    return res        
# Define the path to your JSON file
json_file_path = "top.json"  # Change this to your actual path

# Read JSON file
with open(json_file_path, "r") as file:
    data = json.load(file)

virt_old=[]
for i in range(len(data)):
    virt_old.append(data[i]["VIRT"])


# print(type(data),data[0])

# sorted_data = bubble_sort(data)

sorted_data = selection_sort(data)
output_file_path = "sorted_data.json"

# Write the sorted data to the file with indentation for readability
with open(output_file_path, "w") as outfile:
    json.dump(sorted_data, outfile, indent=4)

print(f"Sorted data saved to {output_file_path}")
virt_new=[]
for i in range(len(sorted_data)):
    virt_new.append(sorted_data[i]["VIRT"])

print(virt_old)

print(virt_new)
print()
r=0
virt_new_int = [int(x) for x in virt_new]  # or float(x) if you have decimal values
for i in range(len(virt_new_int)-1):
    print(virt_new_int[i+1] - virt_new_int[i])
